# %%
# (¯`·.¸¸.·´¯`·.¸¸.-> 𝓙Ⓐ𝕜ᗴ 丅ⓗ乇 ｓภΔ𝐊ᗴ <-.¸¸.·´¯`·.¸¸.·´¯)

# H͓̽o͓̽w͓̽ ͓̽s͓̽t͓̽o͓̽n͓̽e͓̽ ͓̽a͓̽g͓̽e͓̽d͓̽ ͓̽c͓̽o͓̽d͓̽e͓̽r͓̽s͓̽ ͓̽w͓̽o͓̽u͓̽l͓̽d͓̽ ͓̽h͓̽a͓̽v͓̽e͓̽ ͓̽d͓̽o͓̽n͓̽e͓̽ ͓̽t͓̽h͓̽i͓̽s͓̽ ͓̽p͓̽r͓̽o͓̽b͓̽l͓̽e͓̽m͓̽:͓̽

# def findjake(x):
#     i = 0
#     j = 0
#     for elt in x:
#         for ele in elt:
#             if ele == "$":
#                 result = [j, i]
#                 return result
#             i += 1
#         i = 0
#         j += 1
        
# def navigation(q):
#     jake_pos = findjake(q)
#     food = True
#     pos_dict = {"up":False, "down":False, "right":False, "left":False}
#     paths = 0
#     moves = []
    
#     while food == True:
#         print(jake_pos)
#         if q[jake_pos[0]][jake_pos[1]-1] == " " or q[jake_pos[0]][jake_pos[1]-1] == "F":
#             pos_dict["up"] = True
#             paths += 1
#         if q[jake_pos[0]][jake_pos[1]+1] == " " or q[jake_pos[0]][jake_pos[1]+1] == "F":
#             pos_dict["down"] = True
#             paths += 1
#         if q[jake_pos[0]+1][jake_pos[1]] == " " or q[jake_pos[0]+1][jake_pos[1]] == "F":
#             pos_dict["right"] = True
#             paths += 1
#         if q[jake_pos[0]-1][jake_pos[1]] == " " or q[jake_pos[0]-1][jake_pos[1]] == "F":
#             pos_dict["left"] = True
#             paths += 1
#         past_pos = jake_pos 
#         q[past_pos[0]][past_pos[1]] = "+"
#         if paths == 0:
#             break
#         if paths == 1:
#             paths = 0
#             for elt in pos_dict:
#                 if elt == "up":
#                     if pos_dict[elt] == True:
#                         jake_pos[1] = jake_pos[1]-1
#                         moves.append("left")
#                         pos_dict["up"] = False
#                 if elt == "down":
#                     if pos_dict[elt] == True:
#                         jake_pos[1] = jake_pos[1]+1
#                         moves.append("right")
#                         pos_dict["down"] = False
#                 if elt == "right":
#                     if pos_dict[elt] == True:
#                         jake_pos[0] = jake_pos[0]+1
#                         moves.append("down")
#                         pos_dict["right"] = False
#                 if elt == "left":
#                     if pos_dict[elt] == True:
#                         jake_pos[0] = jake_pos[0]-1
#                         moves.append("up")
#                         pos_dict["left"] = False
#             if q[jake_pos[0]][jake_pos[1]] == "F":
#                 food = False
#     return ",`".join(moves)

def findjake(x):
    i = 0
    j = 0
    for elt in x:
        for ele in elt:
            if ele == "$":
                result = [j, i]
                return result
            i += 1
        i = 0
        j += 1
        
def navigation(q):
    jake_pos = findjake(q)
    food = True
    pos_dict = {"up":False, "down":False, "right":False, "left":False}
    paths = 0
    moves = []
    
    while food == True:
        print(jake_pos)
        if q[jake_pos[0]-1][jake_pos[1]] == " " or q[jake_pos[0]-1][jake_pos[1]] == "F":
            pos_dict["up"] = True
            paths += 1
        if q[jake_pos[0]+1][jake_pos[1]] == " " or q[jake_pos[0]+1][jake_pos[1]] == "F":
            pos_dict["down"] = True
            paths += 1
        if q[jake_pos[0]][jake_pos[1]-1] == " " or q[jake_pos[0]][jake_pos[1]-1] == "F":
            pos_dict["left"] = True
            paths += 1
        if q[jake_pos[0]][jake_pos[1]+1] == " " or q[jake_pos[0]][jake_pos[1]+1] == "F":
            pos_dict["right"] = True
            paths += 1
        past_pos = jake_pos 
        q[past_pos[0]][past_pos[1]] = "+"
        if paths == 0 or paths > 1:
            print("【W】【h】【y】 【d】【i】【d】 【y】【o】【u】 【t】【r】【y】 【a】 【f】【o】【r】【k】【i】【n】【g】 【r】【o】【a】【d】 【m】【8】【?】")
            break
        if paths == 1:
            paths = 0
            for elt in pos_dict:
                if elt == "up":
                    if pos_dict[elt] == True:
                        jake_pos[0] = jake_pos[0]-1
                        moves.append("up")
                        pos_dict["up"] = False
                if elt == "down":
                    if pos_dict[elt] == True:
                        jake_pos[0] = jake_pos[0]+1
                        moves.append("down")
                        pos_dict["down"] = False
                if elt == "left":
                    if pos_dict[elt] == True:
                        jake_pos[1] = jake_pos[1]-1
                        moves.append("left")
                        pos_dict["left"] = False
                if elt == "right":
                    if pos_dict[elt] == True:
                        jake_pos[1] = jake_pos[1]+1
                        moves.append("right")
                        pos_dict["right"] = False
            if q[jake_pos[0]][jake_pos[1]] == "F":
                food = False
    return ",`".join(moves)

navigation([['+', '-', '+', '-', '+', '-', '+'],

            ['|', ' ', ' ', ' ', ' ', ' ', '|'],

            ['+', ' ', '+', '-', '+', ' ', '+'],

            ['|', ' ', ' ', 'F', '|', ' ', '|'],

            ['+', '-', '+', '-', '+', ' ', '+'],

            ['|', '$', ' ', ' ', ' ', ' ', '|'],

            ['+', '-', '+', '-', '+', '-', '+']])
# Out:
# [5, 1]
# [5, 2]
# [5, 3]
# [5, 4]
# [5, 5]
# [4, 5]
# [3, 5]
# [2, 5]
# [1, 5]
# [1, 4]
# [1, 3]
# [1, 2]
# [1, 1]
# [2, 1]
# [3, 1]
# [3, 2]
# 'right,`right,`right,`right,`up,`up,`up,`up,`left,`left,`left,`left,`down,`down,`right,`right'
